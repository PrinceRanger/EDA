# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
IMDB = pd.read_csv(r"P:\SEM_3\Manjunath Sir\IMDB-Movie-Data - IMDB-Movie-Data.csv")
IMDB
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 1. Display Top 10 Rows of The Dataset

IMDB.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
# 2. Check Last 10 Rows of The Dataset

IMDB.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

IMDB.shape
# Out:
# (1000, 12)

# %% [markdown]
# IMDB datasets have 1000 rows and 12 columns

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

IMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# 5. Check Missing Values In The Dataset

IMDB.isna().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)     True
# Metascore              True
# dtype: bool

# %%
# 6. Drop All The  Missing Values

IMDB.dropna(inplace = True)

# %%
IMDB.isna().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)    False
# Metascore             False
# dtype: bool

# %%
# 7. Check For Duplicate Data

IMDB.duplicated().any()
# Out:
# False

# %%
IMDB.duplicated().sum()
# Out:
# 0

# %%
# 8. Get Overall Statistics About The DataFrame

IMDB.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# 9. Display Title of The Movie Having Runtime Greater Than or equal to 180 Minutes

large_movies = IMDB[['Title','Runtime (Minutes)']]
big_movie = large_movies[large_movies['Runtime (Minutes)']>=180]
big_movie['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %%
# 10. In Which Year There Was The Highest Average Voting?


average_voting_by_year = IMDB.groupby('Year')['Votes'].mean()
average_voting_by_year
# Out:
# Year
# 2006    277232.219512
# 2007    266530.704545
# 2008    266580.145833
# 2009    267180.577778
# 2010    261082.929825
# 2011    259254.736842
# 2012    290861.483871
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
highest_average_year = average_voting_by_year.idxmax()
highest_average_year
# Out:
# 2012

# %%
# 11. In Which Year There Was The Highest Average Revenue?

avg_high_revenue_by_year = IMDB.groupby('Year')['Revenue (Millions)'].mean()
avg_high_revenue_by_year
# Out:
# Year
# 2006     87.255610
# 2007     93.074091
# 2008     97.525417
# 2009    115.742000
# 2010    105.081579
# 2011     93.703333
# 2012    110.103065
# 2013     88.084643
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %%
highest_revenue_year = avg_high_revenue_by_year.idxmax()
highest_revenue_year
# Out:
# 2009

# %%
# 12. Find The Average Rating For Each Director

avg_rating_directors = IMDB.groupby('Director')['Rating'].mean()
avg_rating_directors
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam McKay             7.00
# Adam Shankman          6.30
# Adam Wingard           5.90
#                        ...
# Xavier Dolan           8.10
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 524, dtype: float64

# %%
# 13. Display Top 10 Lengthy Movies Title and Runtime

lengthy_movies_10 = IMDB.sort_values(by = 'Runtime (Minutes)' , ascending = False).head(10)
lengthy_movies_10
# Out:
#      Rank                                     Title                     Genre  \
# 88     89                         The Hateful Eight       Crime,Drama,Mystery
# 82     83                   The Wolf of Wall Street    Biography,Comedy,Crime
# 311   312                            La vie d'Adèle             Drama,Romance
# 267   268                               Cloud Atlas              Drama,Sci-Fi
# 430   431                                  3 Idiots              Comedy,Drama
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 36     37                              Interstellar    Adventure,Drama,Sci-Fi
# 271   272         The Hobbit: An Unexpected Journey         Adventure,Fantasy
# 425   426       The Curious Case of Benjamin Button     Drama,Fantasy,Romance
# 126   127           Transformers: Age of Extinction   Action,Adventure,Sci-Fi
#
#                                            Description             Director  \
# ...

# %%
# 14. Display Number of Movies Per Year

movies_per_year = IMDB['Year'].value_counts().sort_index()
movies_per_year
# Out:
# 2006     41
# 2007     44
# 2008     48
# 2009     45
# 2010     57
# 2011     57
# 2012     62
# 2013     84
# 2014     93
# 2015    109
# 2016    198
# Name: Year, dtype: int64

# %%
# 15. Find Most Popular Movie Title (Highest Revenue)

most_popular_movie = IMDB.sort_values(by='Revenue (Millions)', ascending=False).head(1)
most_popular_movie
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
# 16. Display Top 10 Highest Rated Movie Titles And its Directors


top_10_highest_rated = IMDB.sort_values(by='Rating', ascending=False).head(10)
top_10_highest_rated[['Title','Director']]
# Out:
#                      Title                          Director
# 54         The Dark Knight                 Christopher Nolan
# 80               Inception                 Christopher Nolan
# 36            Interstellar                 Christopher Nolan
# 249       The Intouchables                   Olivier Nakache
# 96           Kimi no na wa                    Makoto Shinkai
# 124  The Dark Knight Rises                 Christopher Nolan
# 991       Taare Zameen Par                        Aamir Khan
# 133               Whiplash                   Damien Chazelle
# 99            The Departed                   Martin Scorsese
# 476    The Lives of Others  Florian Henckel von Donnersmarck

# %%
# 17. Display Top 10 Highest Revenue Movie Titles

top10_highest_revenue = IMDB.sort_values(by = 'Revenue (Millions)' , ascending = False).head(10)
top10_highest_revenue
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 87     88                                      Avatar
# 85     86                              Jurassic World
# 76     77                                The Avengers
# 54     55                             The Dark Knight
# 12     13                                   Rogue One
# 119   120                                Finding Dory
# 94     95                     Avengers: Age of Ultron
# 124   125                       The Dark Knight Rises
# 578   579             The Hunger Games: Catching Fire
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 87     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 76                Action,Sci-Fi
# 54           Action,Crime,Drama
# 12      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 94      Action,Adventure,Sci-Fi
# 124             Action,Thriller
# 578    Action,Adventure,Mystery
#
# ...

# %%
# 18.  Find Average Rating of Movies Year Wise

average_rating_by_year = IMDB.groupby('Year')['Rating'].mean()
average_rating_by_year
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
# 19. Does Rating Affect The Revenue?

rating_revenue = IMDB[['Title','Rating' , 'Revenue (Millions)']]
rating_revenue
# Out:
#                         Title  Rating  Revenue (Millions)
# 0     Guardians of the Galaxy     8.1              333.13
# 1                  Prometheus     7.0              126.46
# 2                       Split     7.3              138.12
# 3                        Sing     7.2              270.32
# 4               Suicide Squad     6.2              325.02
# ..                        ...     ...                 ...
# 993  Resident Evil: Afterlife     5.9               60.13
# 994                 Project X     6.7               54.72
# 996           Hostel: Part II     5.5               17.54
# 997    Step Up 2: The Streets     6.2               58.01
# 999                Nine Lives     5.3               19.64
#
# [838 rows x 3 columns]

# %%
plt.figure(figsize=(12,8))

plt.scatter(rating_revenue['Rating'],rating_revenue['Revenue (Millions)'], label = 'Data Points' , color = 'brown')
plt.title("RELATION BETWEEN RATING AND REVENUES")
plt.xlabel("RATINGS")
plt.ylabel("REVENUE (Millions)")
plt.grid(True)
plt.show()

# %%
# 20. Classify Movies Based on Ratings [Excellent, Good, and Average]

def grades(Rating):
    if Rating >= 8:
        return 'EXCELLENT'
    elif Rating >= 5:
        return 'GOOD'
    else:
        return 'AVERAGE'
    
IMDB['Grade']=IMDB['Rating'].apply(grades)
IMDB
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 21. Count Number of Action Movies

action_counts = IMDB['Genre'].astype(str).str.contains('Action').sum()
action_counts
# Out:
# 277

# %%
# 22. Find Unique Values From Genre 

IMDB['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Comedy',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Crime,Drama,Mystery',
#        'Drama,Romance,Thriller', 'Drama,History,Thriller',
# ...

# %%
# 23. How Many Films of Each Genre Were Made?

IMDB.groupby('Title')['Genre'].value_counts()
# Out:
# Title                 Genre
# (500) Days of Summer  Comedy,Drama,Romance          1
# 10 Cloverfield Lane   Drama,Horror,Mystery          1
# 12 Years a Slave      Biography,Drama,History       1
# 127 Hours             Adventure,Biography,Drama     1
# 13 Hours              Action,Drama,History          1
#                                                    ..
# Zero Dark Thirty      Drama,History,Thriller        1
# Zodiac                Crime,Drama,History           1
# Zombieland            Adventure,Comedy,Horror       1
# Zoolander 2           Comedy                        1
# Zootopia              Animation,Adventure,Comedy    1
# Name: Genre, Length: 838, dtype: int64

# %%
IMDB
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
